# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Parameters

# %%
# General constants
g = 9.8 # m/s^2
rho = 1025 # kg/m^3

# %% [markdown]
# ## Scour depth
