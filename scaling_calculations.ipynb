# %% [markdown]
# Scaling

# %%
#Parameters

# %%
n_L = h_p / h_m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 n_L = h_p / h_m
#
# NameError: name 'h_p' is not defined
